# %% [markdown]
# <a href="https://colab.research.google.com/github/Clalloures/VisaoComputacional/blob/master/RGB_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

img = cv2.imread('image1.jpg')

# Set blue and green channels to 0

img[:,:,1] = 0
img[:,:,2] = 0

cv2_imshow(img)

plt.imshow(img, cmap='Reds')
# Out:
# <PIL.Image.Image image mode=RGB size=1800x1200 at 0x7F90C9713E90>
